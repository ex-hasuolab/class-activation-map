# %%
# Dataloader ： utils/loder.pyに記述するべき内容
import numpy as np
import cv2
from math import ceil
from scipy import ndimage
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras import utils
import keras
from tensorflow.keras.datasets.mnist import load_data
from keras.preprocessing.image import ImageDataGenerator
import os
import glob
import tensorflow as tf
from PIL import Image
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 完成
def xml_to_labels(annotation_file):
    '''
    指定したxmlファイル(JSON)から、画像ファイル名とアノテーションを取得する
    bboxはJSONの第1層のもののみ取得
    （例：object=personの中に hand, foot...等が含まれるデータもある）
    
    Parameters
    --------------
    annotations_file : str (or pathlib.PosixPath)
        xmlファイルパス

    Returns
    --------------
    img_filename : str
        画像ファイル名
    df_annotations : pandas.DataFrame, shape=(num_object, 5)
        画像に写っている物体(num_object個)に対し、下記の5つのカラムを持つDF
        ・xmin: BBOXのx座標のmin
        ・ymin: BBOXのy座標のmin
        ・xmax: BBOXのx座標のmax
        ・ymax: BBOXのy座標のmax
        ・label: クラスラベル
    '''
    with open(annotation_file) as f:
        xml_data = f.read()  # xmlファイルの内容を読み込む

    # xml操作
    root = ET.XML(xml_data)
    obj_to_int = lambda x: int(x.text)
    df_annotations = pd.DataFrame(columns=['xmin', 'ymin', 'xmax', 'ymax', 'width', 'height', 'name', "pose", "truncated", "difficult"])
    for i, child in enumerate(root):
        if child.tag == 'folder':
            folder = child.text   
        if child.tag == 'filename':
            filename = child.text        
        if child.tag == 'path':
            path = child.text                   
        if child.tag == 'segmented':
            segmented = child.text
            
        if child.tag == 'source':
            for subchild in child:
                if subchild.tag == "database":
                    database = subchild.text
                    
        if child.tag == 'size':
            for subchild in child:
                if subchild.tag == 'width':
                    width = int(subchild.text)
                if subchild.tag == 'height':
                    height = int(subchild.text)
                if subchild.tag == 'depth':
                    depth = int(subchild.text)
                    
                    
        if child.tag == 'object':
            # 各objectにname,bndboxタグが必ず1つのみついていることを想定して値を読み取る
            for subchild in child:
                if subchild.tag == 'pose':
                    pose = subchild.text
                if subchild.tag == 'truncated':
                    truncated = subchild.text
                if subchild.tag == 'difficult':
                    difficult = subchild.text
                if subchild.tag == 'name':
                    label = subchild.text
                if subchild.tag == 'bndbox':
                    xmin, ymin, xmax, ymax = tuple(map(obj_to_int, subchild.getchildren()))
            # BBOXの幅と高さを計算
            #w = xmax - xmin
            #h = ymax - ymin
            # DFに追加
            df_annotations = df_annotations.append(
                {"folder" : folder, "filename" : filename, "path" : path, "database" : database, "segmented": segmented, 'xmin': xmin, 'ymin': ymin, 'xmax': xmax, 'ymax': ymax, 'width': width, "depth" : depth, 'height': height, 'name': label, "pose" : pose, "truncated" : truncated, "difficult" : difficult},
                ignore_index=True
            )
    return df_annotations

# %%
# 完成
def csv_to_labels(annotation_file):
    df_annotations = pd.read_csv(annotation_file)
    img_filename = os.path.splitext(annotation_file.split("/")[-1])[0]
    return img_filename, df_annotations

# %%
# 完成
def get_trimed_img(img, ws, hs, trimed_img_shape):
    trimed_img = {}
    zettai_pos = {}
    
    cnt = 0

    for h in range(hs):
        for w in range(ws):
            x_start = trimed_img_shape[1] * w
            y_start = trimed_img_shape[0] * h
            x_end = x_start+trimed_img_shape[1]
            y_end = y_start+trimed_img_shape[0]

            if x_start+trimed_img_shape[1] >= img.shape[1]:
                x_start = img.shape[1] - trimed_img_shape[1]
                x_end = img.shape[1]

            if y_start+trimed_img_shape[0] >= img.shape[0]:
                y_start = img.shape[0] - trimed_img_shape[0]
                y_end = img.shape[0]
     
            trimed_img[cnt] = img[y_start:y_end,x_start:x_end]           
            zettai_pos[cnt] = {"x_start": x_start, "x_end": x_end, "y_start": y_start, "y_end": y_end}
            cnt = cnt + 1
    return trimed_img, zettai_pos

# %%
# 完成

def get_trimed_bbox(df_annotations, zettai_pos, trimed_img_shape):
    trimed_bbox = {}
    for i in range(len(zettai_pos.keys())):
    #     print("x_start : ", zettai_pos[i]["x_start"])
    #     print("x_end : ", zettai_pos[i]["x_end"])
    #     print("y_start : ", zettai_pos[i]["y_start"])
    #     print("y_end : ", zettai_pos[i]["y_end"])
        df_x_trimed = df_annotations[(df_annotations["xmax"] >= zettai_pos[i]["x_start"]) & (df_annotations["xmin"] <= zettai_pos[i]["x_end"])]
        df_x_trimed.loc[df_x_trimed["xmin"] <= zettai_pos[i]["x_start"], ["xmin"]] = zettai_pos[i]["x_start"]
        df_x_trimed.loc[df_x_trimed["xmax"] >= zettai_pos[i]["x_end"], ["xmax"]] = zettai_pos[i]["x_end"]

        df_x_y_trimed = df_x_trimed[(df_x_trimed["ymax"] >= zettai_pos[i]["y_start"]) & (df_x_trimed["ymin"] <= zettai_pos[i]["y_end"])]
        df_x_y_trimed.loc[df_x_y_trimed["ymin"] <= zettai_pos[i]["y_start"], ["ymin"]] = zettai_pos[i]["y_start"]
        df_x_y_trimed.loc[df_x_y_trimed["ymax"] >= zettai_pos[i]["y_end"], ["ymax"]] = zettai_pos[i]["y_end"]
              
        # todo broadcast演算で出てくるwarning消す
        df_x_y_trimed[["xmin", "xmax"]] = df_x_y_trimed[["xmin", "xmax"]] - zettai_pos[i]["x_start"] 
        df_x_y_trimed[["ymin", "ymax"]] = df_x_y_trimed[["ymin", "ymax"]] - zettai_pos[i]["y_start"]
        df_x_y_trimed['width'] = trimed_img_shape[1]
        df_x_y_trimed['height'] = trimed_img_shape[0]
        trimed_bbox[i] = df_x_y_trimed
        
    return trimed_bbox

# %%
# 完成
def run_trim(img, df_annotations, trimed_img_shape):
    ws = img.shape[1] // trimed_img_shape[1] + 1
    hs = img.shape[0] // trimed_img_shape[0] + 1
    print("横方向 : ", ws)
    print("縦方向 : ", hs)
    print("{} images will be created".format(ws * hs))
    
    trimed_img, zettai_pos = get_trimed_img(img, ws, hs, trimed_img_shape)
    trimed_bbox = get_trimed_bbox(df_annotations, zettai_pos, trimed_img_shape)
    return trimed_img, trimed_bbox

# %%
test = "a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png"

# %%
def add_one_object(roots, row):
    object_ = ET.SubElement(roots, 'object')
    name = ET.SubElement(object_, 'name')
    name.text = row["name"]
    pose = ET.SubElement(object_, 'pose')
    pose.text = row["pose"]
    truncated = ET.SubElement(object_, 'truncated')
    truncated.text = row["truncated"]
    difficult = ET.SubElement(object_, 'difficult')
    difficult.text = row["difficult"]

    bndbox = ET.SubElement(object_, 'bndbox')
    xmin = ET.SubElement(bndbox, 'xmin')
    xmin.text = str(row["xmin"])
    ymin = ET.SubElement(bndbox, 'ymin')
    ymin.text = str(row["ymin"])
    xmax = ET.SubElement(bndbox, 'xmax')
    xmax.text = str(row["xmax"])
    ymax = ET.SubElement(bndbox, 'ymax')
    ymax.text = str(row["ymax"])
    return roots

def make_xml(dc, trim_id):
    roots = ET.Element('annotation')
    folder = ET.SubElement(roots, 'folder')
    folder.text = dc["folder"].iloc[0]
    filename = ET.SubElement(roots, 'filename')
    filename.text = "{0}_{1}.{2}".format(dc["filename"].iloc[0].split(".")[0], trim_id, dc["filename"].iloc[0].split(".")[-1])
    path = ET.SubElement(roots, 'path')
    path.text = dc["path"].iloc[0]
    source = ET.SubElement(roots, 'source')
    database = ET.SubElement(source, "database") 
    database.text = dc["database"].iloc[0]
    
    size = ET.SubElement(roots, 'size')
    width = ET.SubElement(size, "width") 
    width.text = str(dc["width"].iloc[0])
    height = ET.SubElement(size, "height") 
    height.text = str(dc["height"].iloc[0])
    depth = ET.SubElement(size, "depth") 
    depth.text = str(dc["depth"].iloc[0])

    segmented = ET.SubElement(roots, 'segmented')
    segmented.text = dc["segmented"].iloc[0]
    
    # 以下をforループで回したい
    for index, row in dc.iterrows():
        roots = add_one_object(roots, row)
     
    #XML文字列の出力
    ET.dump(roots)

    #XMLファイルの生成
    tree = ET.ElementTree(roots) 

    # 生成したXMLファイル名を返す
    return tree

# %%
# todo 関数化・変数名揃える
def main(original_data_path, output_data_path):
    image_filenames = glob.glob(original_data_path + "/*.png")
    annotation_filenames = glob.glob(original_data_path + "/*.xml")
    assert len(image_filenames) == len(annotation_filenames),"画像とアノテーションファイルの数が違います"

    num = len(image_filenames)   
    trimed_imgs = {}
    trimed_bboxes = {}

    for i in range(num):
        # annotationファイル名を基準に画像を読み込む
        df_annotations = xml_to_labels(annotation_filenames[i])
        img = cv2.imread(original_data_path + df_annotations["filename"][0])

        # triming 実行
        trimed_imgs["image {}".format(i)], trimed_bboxes["image {}".format(i)] = run_trim(img, df_annotations, trimed_img_shape = (650,650)) # todo 繋ぎこみ

    for i, image_id in enumerate(trimed_imgs):
        for trim_id in trimed_imgs[image_id]:
            # 画像ファイルの保存
            filename = "{0}_{1}".format(os.path.splitext(annotation_filenames[i].split("/")[-1])[0], trim_id)
            cv2.imwrite(output_data_path + "{}.png".format(filename), trimed_imgs[image_id][trim_id])
            
            
            # xmlではなくcsvに保存したい時
            # trimed_bboxes[image_id][trim_id].to_csv(output_data_path + "{}.csv".format(filename))
            
            # annotationが存在している時はxmlファイルを保存する
            df = trimed_bboxes[image_id][trim_id]           
            if len(df) != 0:
                print(len(df))
                tree = make_xml(df, trim_id)
                tree.write(output_data_path + '{}.xml'.format(filename))

# %%
original_data_path = '/home/esaka/notebooks/data2/train/'
output_data_path = '/home/esaka/notebooks/data2/train/trimed/'
main(original_data_path, output_data_path)

# アノテーションが無い画像はここで削除
xml_filenames = glob.glob(output_data_path + "*.xml")
png_filenames = glob.glob(output_data_path + "*.png")
for png_f in png_filenames:
    if any([os.path.splitext(png_f.split("/")[-1])[0]  == os.path.splitext(xml_f.split("/")[-1])[0] for xml_f in xml_filenames]):
         pass
    else:
        # !rm {png_f}
        
xml_filenames = glob.glob(output_data_path + "*.xml")
png_filenames = glob.glob(output_data_path + "*.png")
print(len(png_filenames))
print(len(xml_filenames))
# Out:
# 横方向 :  11
# 縦方向 :  8
# 88 images will be created
# /home/esaka/.local/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/esaka/.local/lib/python3.6/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 横方向 :  11
# 縦方向 :  8
# 88 images will be created
# 横方向 :  11
# 縦方向 :  8
# 88 images will be created
# 2
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_0.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>553</xmin><ymin>537</ymin><xmax>650</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>536</xmin><ymin>439</ymin><xmax>650</xmax><ymax>481</ymax></bndbox></object></annotation>
# 15
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_1.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>537</ymin><xmax>33</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>439</ymin><xmax>55</xmax><ymax>481</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>76</xmin><ymin>443</ymin><xmax>167</xmax><ymax>484</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>217</xmin><ymin>449</ymin><xmax>302</xmax><ymax>481</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>384</xmin><ymin>447</ymin><xmax>543</xmax><ymax>482</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>237</xmin><ymin>559</ymin><xmax>286</xmax><ymax>585</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>234</xmin><ymin>601</ymin><xmax>291</xmax><ymax>630</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>236</xmin><ymin>645</ymin><xmax>287</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>339</xmin><ymin>555</ymin><xmax>565</xmax><ymax>587</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>341</xmin><ymin>602</ymin><xmax>565</xmax><ymax>632</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>340</xmin><ymin>642</ymin><xmax>565</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>632</xmin><ymin>474</ymin><xmax>650</xmax><ymax>501</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>646</xmin><ymin>557</ymin><xmax>650</xmax><ymax>588</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>638</xmin><ymin>602</ymin><xmax>650</xmax><ymax>633</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>642</xmin><ymin>643</ymin><xmax>650</xmax><ymax>650</ymax></bndbox></object></annotation>
# 22
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_2.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>59</xmin><ymin>427</ymin><xmax>221</xmax><ymax>466</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>474</ymin><xmax>36</xmax><ymax>501</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>99</xmin><ymin>471</ymin><xmax>180</xmax><ymax>505</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>231</xmin><ymin>472</ymin><xmax>307</xmax><ymax>506</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>557</ymin><xmax>20</xmax><ymax>588</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>103</xmin><ymin>557</ymin><xmax>160</xmax><ymax>591</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>236</xmin><ymin>558</ymin><xmax>296</xmax><ymax>590</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>602</ymin><xmax>21</xmax><ymax>633</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>104</xmin><ymin>604</ymin><xmax>161</xmax><ymax>635</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>236</xmin><ymin>603</ymin><xmax>293</xmax><ymax>635</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>643</ymin><xmax>23</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>105</xmin><ymin>646</ymin><xmax>161</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>232</xmin><ymin>644</ymin><xmax>292</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>209</xmin><ymin>361</ymin><xmax>650</xmax><ymax>404</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>354</xmin><ymin>449</ymin><xmax>478</xmax><ymax>487</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>562</xmin><ymin>450</ymin><xmax>650</xmax><ymax>490</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>348</xmin><ymin>560</ymin><xmax>490</xmax><ymax>591</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>350</xmin><ymin>605</ymin><xmax>489</xmax><ymax>638</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>345</xmin><ymin>647</ymin><xmax>488</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult ...
# 12
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_3.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>361</ymin><xmax>264</xmax><ymax>404</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>450</ymin><xmax>156</xmax><ymax>490</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>557</ymin><xmax>60</xmax><ymax>590</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>603</ymin><xmax>62</xmax><ymax>635</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>645</ymin><xmax>44</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>126</xmin><ymin>561</ymin><xmax>201</xmax><ymax>593</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>132</xmin><ymin>605</ymin><xmax>196</xmax><ymax>637</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>124</xmin><ymin>647</ymin><xmax>198</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>218</xmin><ymin>648</ymin><xmax>311</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>219</xmin><ymin>605</ymin><xmax>306</xmax><ymax>638</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>219</xmin><ymin>560</ymin><xmax>291</xmax><ymax>592</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>332</xmin><ymin>451</ymin><xmax>606</xmax><ymax>491</ymax></bndbox></object></annotation>
# 4
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_4.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>280</xmin><ymin>449</ymin><xmax>502</xmax><ymax>493</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>97</xmin><ymin>562</ymin><xmax>271</xmax><ymax>595</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>99</xmin><ymin>605</ymin><xmax>383</xmax><ymax>640</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>98</xmin><ymin>650</ymin><xmax>272</xmax><ymax>650</ymax></bndbox></object></annotation>
# 5
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_5.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>73</xmin><ymin>590</ymin><xmax>339</xmax><ymax>627</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>444</xmin><ymin>541</ymin><xmax>527</xmax><ymax>576</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>463</xmin><ymin>609</ymin><xmax>509</xmax><ymax>638</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>627</xmin><ymin>542</ymin><xmax>650</xmax><ymax>577</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>605</xmin><ymin>608</ymin><xmax>650</xmax><ymax>640</ymax></bndbox></object></annotation>
# 6
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_6.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>542</ymin><xmax>62</xmax><ymax>577</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>608</ymin><xmax>80</xmax><ymax>640</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>148</xmin><ymin>542</ymin><xmax>276</xmax><ymax>574</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>159</xmin><ymin>610</ymin><xmax>293</xmax><ymax>638</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>398</xmin><ymin>542</ymin><xmax>650</xmax><ymax>578</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>313</xmin><ymin>609</ymin><xmax>650</xmax><ymax>638</ymax></bndbox></object></annotation>
# 6
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_7.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>542</ymin><xmax>38</xmax><ymax>578</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>609</ymin><xmax>121</xmax><ymax>638</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>226</xmin><ymin>541</ymin><xmax>409</xmax><ymax>577</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>631</xmin><ymin>539</ymin><xmax>650</xmax><ymax>582</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>141</xmin><ymin>610</ymin><xmax>209</xmax><ymax>642</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>512</xmin><ymin>614</ymin><xmax>650</xmax><ymax>644</ymax></bndbox></object></annotation>
# 2
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_8.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>539</ymin><xmax>90</xmax><ymax>582</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>614</ymin><xmax>86</xmax><ymax>644</ymax></bndbox></object></annotation>
# 2
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_11.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>546</xmin><ymin>549</ymin><xmax>650</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>553</xmin><ymin>0</ymin><xmax>650</xmax><ymax>17</ymax></bndbox></object></annotation>
# 27
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_12.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>549</ymin><xmax>22</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>0</ymin><xmax>33</xmax><ymax>17</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>236</xmin><ymin>0</ymin><xmax>287</xmax><ymax>23</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>233</xmin><ymin>41</ymin><xmax>293</xmax><ymax>70</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>232</xmin><ymin>82</ymin><xmax>289</xmax><ymax>114</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>233</xmin><ymin>124</ymin><xmax>289</xmax><ymax>159</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>233</xmin><ymin>170</ymin><xmax>288</xmax><ymax>204</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>340</xmin><ymin>0</ymin><xmax>565</xmax><ymax>27</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>338</xmin><ymin>40</ymin><xmax>565</xmax><ymax>71</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>338</xmin><ymin>79</ymin><xmax>565</xmax><ymax>115</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>337</xmin><ymin>126</ymin><xmax>497</xmax><ymax>158</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>337</xmin><ymin>171</ymin><xmax>494</xmax><ymax>204</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>222</xmin><ymin>518</ymin><xmax>282</xmax><ymax>554</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>224</xmin><ymin>565</ymin><xmax>282</xmax><ymax>598</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>226</xmin><ymin>610</ymin><xmax>282</xmax><ymax>643</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>330</xmin><ymin>522</ymin><xmax>557</xmax><ymax>558</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>329</xmin><ymin>568</ymin><xmax>559</xmax><ymax>598</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>329</xmin><ymin>611</ymin><xmax>559</xmax><ymax>643</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>642</xmin><ymin>0</ymin><xmax>650</xmax><ymax>28</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox> ...
# 44
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_13.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>231</xmin><ymin>525</ymin><xmax>290</xmax><ymax>560</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>505</xmin><ymin>522</ymin><xmax>650</xmax><ymax>559</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>0</ymin><xmax>23</xmax><ymax>28</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>105</xmin><ymin>0</ymin><xmax>161</xmax><ymax>29</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>232</xmin><ymin>0</ymin><xmax>292</xmax><ymax>27</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>40</ymin><xmax>22</xmax><ymax>71</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>83</ymin><xmax>20</xmax><ymax>116</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>126</ymin><xmax>20</xmax><ymax>161</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>173</ymin><xmax>19</xmax><ymax>206</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>216</ymin><xmax>19</xmax><ymax>250</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>103</xmin><ymin>41</ymin><xmax>160</xmax><ymax>74</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>101</xmin><ymin>84</ymin><xmax>159</xmax><ymax>118</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>100</xmin><ymin>128</ymin><xmax>162</xmax><ymax>161</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>101</xmin><ymin>173</ymin><xmax>157</xmax><ymax>208</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>101</xmin><ymin>218</ymin><xmax>158</xmax><ymax>251</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>242</xmin><ymin>43</ymin><xmax>291</xmax><ymax>72</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>238</xmin><ymin>82</ymin><xmax>292</xmax><ymax>118</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>250</xmin><ymin>127</ymin><xmax>287</xmax><ymax>161</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>248</xmin><ymin>173</ymin><xmax>288</xmax><ymax>207</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>242</x ...
# 21
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_14.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>522</ymin><xmax>53</xmax><ymax>559</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>0</ymin><xmax>44</xmax><ymax>29</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>43</ymin><xmax>58</xmax><ymax>74</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>83</ymin><xmax>60</xmax><ymax>119</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>124</xmin><ymin>0</ymin><xmax>198</xmax><ymax>32</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>124</xmin><ymin>46</ymin><xmax>199</xmax><ymax>78</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>123</xmin><ymin>86</ymin><xmax>198</xmax><ymax>122</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>570</ymin><xmax>51</xmax><ymax>601</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>613</ymin><xmax>50</xmax><ymax>647</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>118</xmin><ymin>525</ymin><xmax>193</xmax><ymax>564</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>116</xmin><ymin>573</ymin><xmax>193</xmax><ymax>606</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>116</xmin><ymin>615</ymin><xmax>193</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>209</xmin><ymin>616</ymin><xmax>280</xmax><ymax>648</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>211</xmin><ymin>571</ymin><xmax>281</xmax><ymax>606</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>210</xmin><ymin>527</ymin><xmax>283</xmax><ymax>561</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>213</xmin><ymin>219</ymin><xmax>326</xmax><ymax>255</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>211</xmin><ymin>176</ymin><xmax>278</xmax><ymax>209</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>216</xmin><ymin>129</ymin><xmax>387</xmax><ymax>167</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>214</xmin><ymin>87</ymin><xmax>282</xmax><ymax>121</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>2 ...
# 6
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_15.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>98</xmin><ymin>0</ymin><xmax>272</xmax><ymax>35</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>89</xmin><ymin>46</ymin><xmax>415</xmax><ymax>78</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>91</xmin><ymin>88</ymin><xmax>355</xmax><ymax>123</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>88</xmin><ymin>529</ymin><xmax>406</xmax><ymax>566</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>87</xmin><ymin>574</ymin><xmax>354</xmax><ymax>608</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>88</xmin><ymin>616</ymin><xmax>411</xmax><ymax>650</ymax></bndbox></object></annotation>
# 2
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_16.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>463</xmin><ymin>4</ymin><xmax>507</xmax><ymax>31</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>604</xmin><ymin>1</ymin><xmax>650</xmax><ymax>35</ymax></bndbox></object></annotation>
# 3
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_17.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>1</ymin><xmax>81</xmax><ymax>35</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>154</xmin><ymin>5</ymin><xmax>294</xmax><ymax>32</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>313</xmin><ymin>3</ymin><xmax>650</xmax><ymax>34</ymax></bndbox></object></annotation>
# 3
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_18.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>3</ymin><xmax>119</xmax><ymax>34</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>140</xmin><ymin>3</ymin><xmax>215</xmax><ymax>35</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>513</xmin><ymin>4</ymin><xmax>650</xmax><ymax>37</ymax></bndbox></object></annotation>
# 1
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_19.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>4</ymin><xmax>85</xmax><ymax>37</ymax></bndbox></object></annotation>
# 2
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_22.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>546</xmin><ymin>0</ymin><xmax>650</xmax><ymax>30</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>534</xmin><ymin>335</ymin><xmax>650</xmax><ymax>469</ymax></bndbox></object></annotation>
# 33
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_23.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>0</ymin><xmax>22</xmax><ymax>30</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>335</ymin><xmax>15</xmax><ymax>469</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>223</xmin><ymin>2</ymin><xmax>282</xmax><ymax>38</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>219</xmin><ymin>46</ymin><xmax>282</xmax><ymax>82</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>330</xmin><ymin>3</ymin><xmax>556</xmax><ymax>35</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>330</xmin><ymin>50</ymin><xmax>556</xmax><ymax>82</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>219</xmin><ymin>313</ymin><xmax>276</xmax><ymax>344</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>219</xmin><ymin>356</ymin><xmax>276</xmax><ymax>388</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>218</xmin><ymin>397</ymin><xmax>275</xmax><ymax>433</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>218</xmin><ymin>444</ymin><xmax>276</xmax><ymax>477</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>217</xmin><ymin>489</ymin><xmax>277</xmax><ymax>520</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>218</xmin><ymin>531</ymin><xmax>273</xmax><ymax>564</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>217</xmin><ymin>579</ymin><xmax>279</xmax><ymax>607</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>217</xmin><ymin>621</ymin><xmax>273</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>322</xmin><ymin>311</ymin><xmax>556</xmax><ymax>342</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>322</xmin><ymin>357</ymin><xmax>552</xmax><ymax>387</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>323</xmin><ymin>400</ymin><xmax>550</xmax><ymax>432</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>323</xmin><ymin>443</ymin><xmax>549</xmax><ymax>478</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>322</xmin><ymin>488</ymin><xmax>549</xmax><ymax>521</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bn ...
# 55
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_24.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>224</xmin><ymin>180</ymin><xmax>270</xmax><ymax>215</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>4</ymin><xmax>11</xmax><ymax>37</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>48</ymin><xmax>9</xmax><ymax>82</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>93</ymin><xmax>9</xmax><ymax>126</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>94</xmin><ymin>6</ymin><xmax>152</xmax><ymax>40</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>92</xmin><ymin>49</ymin><xmax>151</xmax><ymax>83</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>94</xmin><ymin>93</ymin><xmax>149</xmax><ymax>127</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>228</xmin><ymin>7</ymin><xmax>285</xmax><ymax>40</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>230</xmin><ymin>50</ymin><xmax>285</xmax><ymax>84</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>312</ymin><xmax>9</xmax><ymax>345</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>358</ymin><xmax>11</xmax><ymax>389</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>401</ymin><xmax>9</xmax><ymax>434</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>446</ymin><xmax>10</xmax><ymax>477</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>488</ymin><xmax>9</xmax><ymax>522</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>533</ymin><xmax>9</xmax><ymax>566</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>578</ymin><xmax>8</xmax><ymax>610</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>620</ymin><xmax>4</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>90</xmin><ymin>314</ymin><xmax>150</xmax><ymax>346</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>91</xmin><ymin>358</ymin><xmax>149</xmax><ymax>389</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>93</xmin><ymin>401</ymin><xmax>14 ...
# 32
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11_25.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-11.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>8</ymin><xmax>49</xmax><ymax>39</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>50</ymin><xmax>51</xmax><ymax>82</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>116</xmin><ymin>0</ymin><xmax>193</xmax><ymax>0</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>115</xmin><ymin>9</ymin><xmax>194</xmax><ymax>42</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>115</xmin><ymin>54</ymin><xmax>191</xmax><ymax>89</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>313</ymin><xmax>29</xmax><ymax>344</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>357</ymin><xmax>47</xmax><ymax>390</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>402</ymin><xmax>31</xmax><ymax>438</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>444</ymin><xmax>30</xmax><ymax>480</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>489</ymin><xmax>31</xmax><ymax>525</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>535</ymin><xmax>47</xmax><ymax>567</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>582</ymin><xmax>52</xmax><ymax>610</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>622</ymin><xmax>53</xmax><ymax>650</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>112</xmin><ymin>313</ymin><xmax>188</xmax><ymax>349</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>112</xmin><ymin>360</ymin><xmax>176</xmax><ymax>395</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>114</xmin><ymin>403</ymin><xmax>188</xmax><ymax>440</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>111</xmin><ymin>449</ymin><xmax>187</xmax><ymax>485</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>111</xmin><ymin>491</ymin><xmax>187</xmax><ymax>528</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>106</xmin><ymin>537</ymin><xmax>184</xmax><ymax>571</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>110</xmin><ymi ...
# 11
# ...
# 6
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13_58.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>43</ymin><xmax>101</xmax><ymax>71</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>353</ymin><xmax>12</xmax><ymax>382</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>405</ymin><xmax>10</xmax><ymax>436</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>458</ymin><xmax>121</xmax><ymax>486</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>508</ymin><xmax>209</xmax><ymax>537</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>561</ymin><xmax>118</xmax><ymax>590</ymax></bndbox></object></annotation>
# 9
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13_59.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>197</xmin><ymin>0</ymin><xmax>271</xmax><ymax>35</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>195</xmin><ymin>143</ymin><xmax>270</xmax><ymax>189</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>194</xmin><ymin>196</ymin><xmax>269</xmax><ymax>241</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>294</xmin><ymin>0</ymin><xmax>346</xmax><ymax>28</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>500</xmin><ymin>49</ymin><xmax>551</xmax><ymax>78</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>292</xmin><ymin>151</ymin><xmax>342</xmax><ymax>183</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>292</xmin><ymin>201</ymin><xmax>343</xmax><ymax>235</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>496</xmin><ymin>257</ymin><xmax>547</xmax><ymax>286</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>609</xmin><ymin>50</ymin><xmax>650</xmax><ymax>78</ymax></bndbox></object></annotation>
# 13
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13_60.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>50</ymin><xmax>39</xmax><ymax>78</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>66</xmin><ymin>0</ymin><xmax>111</xmax><ymax>28</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>64</xmin><ymin>153</ymin><xmax>105</xmax><ymax>183</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>64</xmin><ymin>206</ymin><xmax>103</xmax><ymax>236</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>127</xmin><ymin>0</ymin><xmax>177</xmax><ymax>27</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>123</xmin><ymin>153</ymin><xmax>177</xmax><ymax>185</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>121</xmin><ymin>205</ymin><xmax>178</xmax><ymax>235</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>191</xmin><ymin>0</ymin><xmax>245</xmax><ymax>28</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>191</xmin><ymin>155</ymin><xmax>241</xmax><ymax>186</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>190</xmin><ymin>205</ymin><xmax>241</xmax><ymax>236</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>259</xmin><ymin>0</ymin><xmax>338</xmax><ymax>29</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>257</xmin><ymin>155</ymin><xmax>336</xmax><ymax>186</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>256</xmin><ymin>204</ymin><xmax>336</xmax><ymax>237</ymax></bndbox></object></annotation>
# 13
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13_61.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>445</xmin><ymin>5</ymin><xmax>650</xmax><ymax>43</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>443</xmin><ymin>64</ymin><xmax>650</xmax><ymax>103</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>442</xmin><ymin>124</ymin><xmax>650</xmax><ymax>161</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>441</xmin><ymin>183</ymin><xmax>650</xmax><ymax>217</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>440</xmin><ymin>244</ymin><xmax>650</xmax><ymax>279</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>440</xmin><ymin>301</ymin><xmax>650</xmax><ymax>337</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>442</xmin><ymin>363</ymin><xmax>650</xmax><ymax>395</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>645</xmin><ymin>422</ymin><xmax>650</xmax><ymax>455</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>646</xmin><ymin>482</ymin><xmax>650</xmax><ymax>516</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>488</xmin><ymin>411</ymin><xmax>635</xmax><ymax>462</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>486</xmin><ymin>470</ymin><xmax>637</xmax><ymax>521</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>437</xmin><ymin>541</ymin><xmax>650</xmax><ymax>574</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>426</xmin><ymin>600</ymin><xmax>650</xmax><ymax>635</ymax></bndbox></object></annotation>
# 13
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13_62.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>5</ymin><xmax>650</xmax><ymax>43</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>64</ymin><xmax>389</xmax><ymax>103</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>124</ymin><xmax>430</xmax><ymax>161</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>183</ymin><xmax>429</xmax><ymax>217</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>244</ymin><xmax>381</xmax><ymax>279</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>301</ymin><xmax>381</xmax><ymax>337</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>363</ymin><xmax>149</xmax><ymax>395</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>422</ymin><xmax>276</xmax><ymax>455</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>482</ymin><xmax>272</xmax><ymax>516</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>541</ymin><xmax>169</xmax><ymax>574</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>600</ymin><xmax>650</xmax><ymax>635</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>510</xmin><ymin>412</ymin><xmax>650</xmax><ymax>469</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>510</xmin><ymin>474</ymin><xmax>650</xmax><ymax>527</ymax></bndbox></object></annotation>
# 6
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13_63.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>5</ymin><xmax>24</xmax><ymax>43</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>600</ymin><xmax>23</xmax><ymax>635</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>25</xmin><ymin>426</ymin><xmax>372</xmax><ymax>457</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>20</xmin><ymin>484</ymin><xmax>370</xmax><ymax>519</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>412</ymin><xmax>17</xmax><ymax>469</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>474</ymin><xmax>15</xmax><ymax>527</ymax></bndbox></object></annotation>
# 1
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13_67.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>585</xmin><ymin>10</ymin><xmax>637</xmax><ymax>39</ymax></bndbox></object></annotation>
# 1
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13_68.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>44</xmin><ymin>10</ymin><xmax>119</xmax><ymax>41</ymax></bndbox></object></annotation>
# 2
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13_72.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>426</xmin><ymin>6</ymin><xmax>650</xmax><ymax>39</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>426</xmin><ymin>66</ymin><xmax>650</xmax><ymax>101</ymax></bndbox></object></annotation>
# 2
# <annotation><folder>Downloads</folder><filename>70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13_73.png</filename><path>C:\Users\9046692\Downloads\70a3bdae-24cf-4162-97b1-3b9f0a01a4e9-13.png</path><source><database>Unknown</database></source><size><width>650</width><height>650</height><depth>1.0</depth></size><segmented>0</segmented><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>6</ymin><xmax>94</xmax><ymax>39</ymax></bndbox></object><object><name>number</name><pose>Unspecified</pose><truncated>0</truncated><difficult>0</difficult><bndbox><xmin>0</xmin><ymin>66</ymin><xmax>302</xmax><ymax>101</ymax></bndbox></object></annotation>
# 127
# 127

# %% [markdown]
# # 画像が正しくトリミング出来ているか確認

# %%
plt.figure(figsize = (20,5))

for i in range(22):
    plt.subplot(2,11,i+1)
    plt.imshow(trimed_img[i])

# %% [markdown]
# # todo bboxが正しく抜けているか確認

# %%
plt.figure(figsize = (20,10))
plt.imshow(img)
